# %% [markdown]
# # Transfer learning
#
# В этом дз вам предстоит дообучить модель ResNet18 на датасете dogs-vs-cats.
#
# Для начала понадобится зарегистрироваться на сайте Kaggle. Это одна из самых известных платформ для соревнований по анализу данных. А ещё там тоже можно пользоваться бесплатными видеокартами, если подтвердить аккаунт по номеру телефона.
#
# Чтобы скачать оттуда интересующий нас датасет, можно воспользоваться инструкцией с сайта:
# https://www.kaggle.com/discussions/general/74235
#
# Заметим, что большую часть мы уже написали для вас, и по инструкции нужно лишь сгенерировать API токен и загрузить его сюда!
#
# После этого необходимо ещё и принять принять правила соревнования (нажать кнопку Join competition и подтвердить согласие).
# Ссылка на соревнование:
# https://www.kaggle.com/c/dogs-vs-cats/data

# %%
from google.colab import files

files.upload()

# %%
# !rm -f dogs-vs-cats.zip
# !kaggle competitions download -c dogs-vs-cats
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle competitions download -c dogs-vs-cats
# !unzip dogs-vs-cats.zip
# !rm test1.zip
# !mkdir -p ./dogcat
# !unzip train.zip -d ./dogcat
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ./dogcat/train/dog.5499.jpg
#   inflating: ./dogcat/train/dog.55.jpg
#   inflating: ./dogcat/train/dog.550.jpg
#   inflating: ./dogcat/train/dog.5500.jpg
#   inflating: ./dogcat/train/dog.5501.jpg
#   inflating: ./dogcat/train/dog.5502.jpg
#   inflating: ./dogcat/train/dog.5503.jpg
#   inflating: ./dogcat/train/dog.5504.jpg
#   inflating: ./dogcat/train/dog.5505.jpg
#   inflating: ./dogcat/train/dog.5506.jpg
#   inflating: ./dogcat/train/dog.5507.jpg
#   inflating: ./dogcat/train/dog.5508.jpg
#   inflating: ./dogcat/train/dog.5509.jpg
#   inflating: ./dogcat/train/dog.551.jpg
#   inflating: ./dogcat/train/dog.5510.jpg
#   inflating: ./dogcat/train/dog.5511.jpg
#   inflating: ./dogcat/train/dog.5512.jpg
#   inflating: ./dogcat/train/dog.5513.jpg
#   inflating: ./dogcat/train/dog.5514.jpg
#   inflating: ./dogcat/train/dog.5515.jpg
#   inflating: ./dogcat/train/dog.5516.jpg
#   inflating: ./dogcat/train/dog.5517.jpg
#   inflating: ./dogcat/train/dog.5518.jpg
#   inflating: ./dogcat/train/dog.5519.jpg
#   inflating: ./dogcat/train/dog.552.jpg
#   inflating: ./dogcat/train/dog.5520.jpg
#   inflating: ./dogcat/train/dog.5521.jpg
#   inflating: ./dogcat/train/dog.5522.jpg
#   inflating: ./dogcat/train/dog.5523.jpg
#   inflating: ./dogcat/train/dog.5524.jpg
#   inflating: ./dogcat/train/dog.5525.jpg
#   inflating: ./dogcat/train/dog.5526.jpg
#   inflating: ./dogcat/train/dog.5527.jpg
#   inflating: ./dogcat/train/dog.5528.jpg
#   inflating: ./dogcat/train/dog.5529.jpg
#   inflating: ./dogcat/train/dog.553.jpg
#   inflating: ./dogcat/train/dog.5530.jpg
#   inflating: ./dogcat/train/dog.5531.jpg
#   inflating: ./dogcat/train/dog.5532.jpg
#   inflating: ./dogcat/train/dog.5533.jpg
#   inflating: ./dogcat/train/dog.5534.jpg
#   inflating: ./dogcat/train/dog.5535.jpg
#   inflating: ./dogcat/train/dog.5536.jpg
#   inflating: ./dogcat/train/dog.5537.jpg
#   inflating: ./dogcat/train/dog.5538.jpg
#   inflating: ./dogcat/train/dog.5539.jpg
#   inflating: ./dogcat/train/dog.554.jpg
#   inflating: ./dogcat/train/dog.5540.jpg
#   inflating: ./dogcat/train/dog.5541.jpg
#   inflating: ./dogcat/train/dog.5542.jpg
#   inflating: ./dogcat/train/dog.5543.jpg
#   inflating: ./dogcat/train/dog.5544.jpg
#   inflating: ./dogcat/train/dog.5545.jpg
#   inflating: ./dogcat/train/dog.5546.jpg
#   inflating: ./dogcat/train/dog.5547.jpg
#   inflating: ./dogcat/train/dog.5548.jpg
#   inflating: ./dogcat/train/dog.5549.jpg
#   inflating: ./dogcat/train/dog.555.jpg
#   inflating: ./dogcat/train/dog.5550.jpg
#   inflating: ./dogcat/train/dog.5551.jpg
#   inflating: ./dogcat/train/dog.5552.jpg
#   inflating: ./dogcat/train/dog.5553.jpg
#   inflating: ./dogcat/train/dog.5554.jpg
#   inflating: ./dogcat/train/dog.5555.jpg
#   inflating: ./dogcat/train/dog.5556.jpg
#   inflating: ./dogcat/train/dog.5557.jpg
#   inflating: ./dogcat/train/dog.5558.jpg
#   inflating: ./dogcat/train/dog.5559.jpg
#   inflating: ./dogcat/train/dog.556.jpg
#   inflating: ./dogcat/train/dog.5560.jpg
#   inflating: ./dogcat/train/dog.5561.jpg
#   inflating: ./dogcat/train/dog.5562.jpg
#   inflating: ./dogcat/train/dog.5563.jpg
#   inflating: ./dogcat/train/dog.5564.jpg
#   inflating: ./dogcat/train/dog.5565.jpg
#   inflating: ./dogcat/train/dog.5566.jpg
#   inflating: ./dogcat/train/dog.5567.jpg
#   inflating: ./dogcat/train/dog.5568.jpg
#   inflating: ./dogcat/train/dog.5569.jpg
#   inflating: ./dogcat/train/dog.557.jpg
#   inflating: ./dogcat/train/dog.5570.jpg
#   inflating: ./dogcat/train/dog.5571.jpg
#   inflating: ./dogcat/train/dog.5572.jpg
#   inflating: ./dogcat/train/dog.5573.jpg
#   inflating: ./dogcat/train/dog.5574.jpg
#   inflating: ./dogcat/train/dog.5575.jpg
#   inflating: ./dogcat/train/dog.5576.jpg
#   inflating: ./dogcat/train/dog.5577.jpg
#   inflating: ./dogcat/train/dog.5578.jpg
#   inflating: ./dogcat/train/dog.5579.jpg
#   inflating: ./dogcat/train/dog.558.jpg
#   inflating: ./dogcat/train/dog.5580.jpg
#   inflating: ./dogcat/train/dog.5581.jpg
#   inflating: ./dogcat/train/dog.5582.jpg
#   inflating: ./dogcat/train/dog.5583.jpg
#   inflating: ./dogcat/train/dog.5584.jpg
#   inflating: ./dogcat/train/dog.5585.jpg
#   inflating: ./dogcat/train/dog.5586.jpg
#   inflating: ./dogcat/train/dog.5587.jpg
#   inflating: ./dogcat/train/dog.5588.jpg
#   inflating: ./dogcat/train/dog.5589.jpg
#   inflating: ./dogcat/train/dog.559.jpg
#   inflating: ./dogcat/train/dog.5590.jpg
#   inflating: ./dogcat/train/dog.5591.jpg
#   inflating: ./dogcat/train/dog.5592.jpg
#   inflating: ./dogcat/train/dog.5593.jpg
#   inflating: ./dogcat/train/dog.5594.jpg
#   inflating: ./dogcat/train/dog.5595.jpg
#   inflating: ./dogcat/train/dog.5596.jpg
#   inflating: ./dogcat/train/dog.5597.jpg
#   inflating: ./dogcat/train/dog.5598.jpg
#   inflating: ./dogcat/train/dog.5599.jpg
#   inflating: ./dogcat/train/dog.56.jpg
#   inflating: ./dogcat/train/dog.560.jpg
#   inflating: ./dogcat/train/dog.5600.jpg
#   inflating: ./dogcat/train/dog.5601.jpg
#   inflating: ./dogcat/train/dog.5602.jpg
#   inflating: ./dogcat/train/dog.5603.jpg
#   inflating: ./dogcat/train/dog.5604.jpg
#   inflating: ./dogcat/train/dog.5605.jpg
#   inflating: ./dogcat/train/dog.5606.jpg
#   inflating: ./dogcat/train/dog.5607.jpg
#   inflating: ./dogcat/train/dog.5608.jpg
#   inflating: ./dogcat/train/dog.5609.jpg
#   inflating: ./dogcat/train/dog.561.jpg
#   inflating: ./dogcat/train/dog.5610.jpg
#   inflating: ./dogcat/train/dog.5611.jpg
#   inflating: ./dogcat/train/dog.5612.jpg
#   inflating: ./dogcat/train/dog.5613.jpg
#   inflating: ./dogcat/train/dog.5614.jpg
#   inflating: ./dogcat/train/dog.5615.jpg
#   inflating: ./dogcat/train/dog.5616.jpg
#   inflating: ./dogcat/train/dog.5617.jpg
#   inflating: ./dogcat/train/dog.5618.jpg
#   inflating: ./dogcat/train/dog.5619.jpg
#   inflating: ./dogcat/train/dog.562.jpg
#   inflating: ./dogcat/train/dog.5620.jpg
#   inflating: ./dogcat/train/dog.5621.jpg
#   inflating: ./dogcat/train/dog.5622.jpg
#   inflating: ./dogcat/train/dog.5623.jpg
#   inflating: ./dogcat/train/dog.5624.jpg
#   inflating: ./dogcat/train/dog.5625.jpg
#   inflating: ./dogcat/train/dog.5626.jpg
#   inflating: ./dogcat/train/dog.5627.jpg
#   inflating: ./dogcat/train/dog.5628.jpg
#   inflating: ./dogcat/train/dog.5629.jpg
#   inflating: ./dogcat/train/dog.563.jpg
#   inflating: ./dogcat/train/dog.5630.jpg
#   inflating: ./dogcat/train/dog.5631.jpg
#   inflating: ./dogcat/train/dog.5632.jpg
#   inflating: ./dogcat/train/dog.5633.jpg
#   inflating: ./dogcat/train/dog.5634.jpg
#   inflating: ./dogcat/train/dog.5635.jpg
#   inflating: ./dogcat/train/dog.5636.jpg
#   inflating: ./dogcat/train/dog.5637.jpg
#   inflating: ./dogcat/train/dog.5638.jpg
#   inflating: ./dogcat/train/dog.5639.jpg
#   inflating: ./dogcat/train/dog.564.jpg
#   inflating: ./dogcat/train/dog.5640.jpg
#   inflating: ./dogcat/train/dog.5641.jpg
#   inflating: ./dogcat/train/dog.5642.jpg
#   inflating: ./dogcat/train/dog.5643.jpg
#   inflating: ./dogcat/train/dog.5644.jpg
#   inflating: ./dogcat/train/dog.5645.jpg
#   inflating: ./dogcat/train/dog.5646.jpg
#   inflating: ./dogcat/train/dog.5647.jpg
#   inflating: ./dogcat/train/dog.5648.jpg
#   inflating: ./dogcat/train/dog.5649.jpg
#   inflating: ./dogcat/train/dog.565.jpg
#   inflating: ./dogcat/train/dog.5650.jpg
#   inflating: ./dogcat/train/dog.5651.jpg
#   inflating: ./dogcat/train/dog.5652.jpg
#   inflating: ./dogcat/train/dog.5653.jpg
#   inflating: ./dogcat/train/dog.5654.jpg
#   inflating: ./dogcat/train/dog.5655.jpg
#   inflating: ./dogcat/train/dog.5656.jpg
#   inflating: ./dogcat/train/dog.5657.jpg
#   inflating: ./dogcat/train/dog.5658.jpg
#   inflating: ./dogcat/train/dog.5659.jpg
#   inflating: ./dogcat/train/dog.566.jpg
#   inflating: ./dogcat/train/dog.5660.jpg
#   inflating: ./dogcat/train/dog.5661.jpg
#   inflating: ./dogcat/train/dog.5662.jpg
#   inflating: ./dogcat/train/dog.5663.jpg
#   inflating: ./dogcat/train/dog.5664.jpg
#   inflating: ./dogcat/train/dog.5665.jpg
#   inflating: ./dogcat/train/dog.5666.jpg
#   inflating: ./dogcat/train/dog.5667.jpg
#   inflating: ./dogcat/train/dog.5668.jpg
#   inflating: ./dogcat/train/dog.5669.jpg
#   inflating: ./dogcat/train/dog.567.jpg
#   inflating: ./dogcat/train/dog.5670.jpg
#   inflating: ./dogcat/train/dog.5671.jpg
#   inflating: ./dogcat/train/dog.5672.jpg
#   inflating: ./dogcat/train/dog.5673.jpg
#   inflating: ./dogcat/train/dog.5674.jpg
#   inflating: ./dogcat/train/dog.5675.jpg
#   inflating: ./dogcat/train/dog.5676.jpg
#   inflating: ./dogcat/train/dog.5677.jpg
#   inflating: ./dogcat/train/dog.5678.jpg
#   inflating: ./dogcat/train/dog.5679.jpg
#   inflating: ./dogcat/train/dog.568.jpg
#   inflating: ./dogcat/train/dog.5680.jpg
#   inflating: ./dogcat/train/dog.5681.jpg
#   inflating: ./dogcat/train/dog.5682.jpg
#   inflating: ./dogcat/train/dog.5683.jpg
#   inflating: ./dogcat/train/dog.5684.jpg
#   inflating: ./dogcat/train/dog.5685.jpg
#   inflating: ./dogcat/train/dog.5686.jpg
#   inflating: ./dogcat/train/dog.5687.jpg
#   inflating: ./dogcat/train/dog.5688.jpg
#   inflating: ./dogcat/train/dog.5689.jpg
#   inflating: ./dogcat/train/dog.569.jpg
#   inflating: ./dogcat/train/dog.5690.jpg
#   inflating: ./dogcat/train/dog.5691.jpg
#   inflating: ./dogcat/train/dog.5692.jpg
#   inflating: ./dogcat/train/dog.5693.jpg
#   inflating: ./dogcat/train/dog.5694.jpg
#   inflating: ./dogcat/train/dog.5695.jpg
#   inflating: ./dogcat/train/dog.5696.jpg
#   inflating: ./dogcat/train/dog.5697.jpg
#   inflating: ./dogcat/train/dog.5698.jpg
#   inflating: ./dogcat/train/dog.5699.jpg
#   inflating: ./dogcat/train/dog.57.jpg
#   inflating: ./dogcat/train/dog.570.jpg
#   inflating: ./dogcat/train/dog.5700.jpg
#   inflating: ./dogcat/train/dog.5701.jpg
#   inflating: ./dogcat/train/dog.5702.jpg
#   inflating: ./dogcat/train/dog.5703.jpg
#   inflating: ./dogcat/train/dog.5704.jpg
#   inflating: ./dogcat/train/dog.5705.jpg
#   inflating: ./dogcat/train/dog.5706.jpg
#   inflating: ./dogcat/train/dog.5707.jpg
#   inflating: ./dogcat/train/dog.5708.jpg
#   inflating: ./dogcat/train/dog.5709.jpg
#   inflating: ./dogcat/train/dog.571.jpg
#   inflating: ./dogcat/train/dog.5710.jpg
#   inflating: ./dogcat/train/dog.5711.jpg
#   inflating: ./dogcat/train/dog.5712.jpg
#   inflating: ./dogcat/train/dog.5713.jpg
#   inflating: ./dogcat/train/dog.5714.jpg
#   inflating: ./dogcat/train/dog.5715.jpg
#   inflating: ./dogcat/train/dog.5716.jpg
#   inflating: ./dogcat/train/dog.5717.jpg
#   inflating: ./dogcat/train/dog.5718.jpg
#   inflating: ./dogcat/train/dog.5719.jpg
#   inflating: ./dogcat/train/dog.572.jpg
#   inflating: ./dogcat/train/dog.5720.jpg
#   inflating: ./dogcat/train/dog.5721.jpg
#   inflating: ./dogcat/train/dog.5722.jpg
#   inflating: ./dogcat/train/dog.5723.jpg
#   inflating: ./dogcat/train/dog.5724.jpg
#   inflating: ./dogcat/train/dog.5725.jpg
#   inflating: ./dogcat/train/dog.5726.jpg
#   inflating: ./dogcat/train/dog.5727.jpg
#   inflating: ./dogcat/train/dog.5728.jpg
#   inflating: ./dogcat/train/dog.5729.jpg
#   inflating: ./dogcat/train/dog.573.jpg
#   inflating: ./dogcat/train/dog.5730.jpg
#   inflating: ./dogcat/train/dog.5731.jpg
#   inflating: ./dogcat/train/dog.5732.jpg
#   inflating: ./dogcat/train/dog.5733.jpg
#   inflating: ./dogcat/train/dog.5734.jpg
#   inflating: ./dogcat/train/dog.5735.jpg
#   inflating: ./dogcat/train/dog.5736.jpg
#   inflating: ./dogcat/train/dog.5737.jpg
#   inflating: ./dogcat/train/dog.5738.jpg
#   inflating: ./dogcat/train/dog.5739.jpg
#   inflating: ./dogcat/train/dog.574.jpg
#   inflating: ./dogcat/train/dog.5740.jpg
#   inflating: ./dogcat/train/dog.5741.jpg
#   inflating: ./dogcat/train/dog.5742.jpg
#   inflating: ./dogcat/train/dog.5743.jpg
#   inflating: ./dogcat/train/dog.5744.jpg
#   inflating: ./dogcat/train/dog.5745.jpg
#   inflating: ./dogcat/train/dog.5746.jpg
#   inflating: ./dogcat/train/dog.5747.jpg
#   inflating: ./dogcat/train/dog.5748.jpg
#   inflating: ./dogcat/train/dog.5749.jpg
#   inflating: ./dogcat/train/dog.575.jpg
#   inflating: ./dogcat/train/dog.5750.jpg
#   inflating: ./dogcat/train/dog.5751.jpg
#   inflating: ./dogcat/train/dog.5752.jpg
#   inflating: ./dogcat/train/dog.5753.jpg
#   inflating: ./dogcat/train/dog.5754.jpg
#   inflating: ./dogcat/train/dog.5755.jpg
#   inflating: ./dogcat/train/dog.5756.jpg
#   inflating: ./dogcat/train/dog.5757.jpg
#   inflating: ./dogcat/train/dog.5758.jpg
#   inflating: ./dogcat/train/dog.5759.jpg
#   inflating: ./dogcat/train/dog.576.jpg
#   inflating: ./dogcat/train/dog.5760.jpg
#   inflating: ./dogcat/train/dog.5761.jpg
#   inflating: ./dogcat/train/dog.5762.jpg
#   inflating: ./dogcat/train/dog.5763.jpg
#   inflating: ./dogcat/train/dog.5764.jpg
#   inflating: ./dogcat/train/dog.5765.jpg
#   inflating: ./dogcat/train/dog.5766.jpg
#   inflating: ./dogcat/train/dog.5767.jpg
#   inflating: ./dogcat/train/dog.5768.jpg
#   inflating: ./dogcat/train/dog.5769.jpg
#   inflating: ./dogcat/train/dog.577.jpg
#   inflating: ./dogcat/train/dog.5770.jpg
#   inflating: ./dogcat/train/dog.5771.jpg
#   inflating: ./dogcat/train/dog.5772.jpg
#   inflating: ./dogcat/train/dog.5773.jpg
#   inflating: ./dogcat/train/dog.5774.jpg
#   inflating: ./dogcat/train/dog.5775.jpg
#   inflating: ./dogcat/train/dog.5776.jpg
#   inflating: ./dogcat/train/dog.5777.jpg
#   inflating: ./dogcat/train/dog.5778.jpg
#   inflating: ./dogcat/train/dog.5779.jpg
#   inflating: ./dogcat/train/dog.578.jpg
#   inflating: ./dogcat/train/dog.5780.jpg
#   inflating: ./dogcat/train/dog.5781.jpg
#   inflating: ./dogcat/train/dog.5782.jpg
#   inflating: ./dogcat/train/dog.5783.jpg
#   inflating: ./dogcat/train/dog.5784.jpg
#   inflating: ./dogcat/train/dog.5785.jpg
#   inflating: ./dogcat/train/dog.5786.jpg
#   inflating: ./dogcat/train/dog.5787.jpg
#   inflating: ./dogcat/train/dog.5788.jpg
#   inflating: ./dogcat/train/dog.5789.jpg
#   inflating: ./dogcat/train/dog.579.jpg
#   inflating: ./dogcat/train/dog.5790.jpg
#   inflating: ./dogcat/train/dog.5791.jpg
#   inflating: ./dogcat/train/dog.5792.jpg
#   inflating: ./dogcat/train/dog.5793.jpg
#   inflating: ./dogcat/train/dog.5794.jpg
#   inflating: ./dogcat/train/dog.5795.jpg
#   inflating: ./dogcat/train/dog.5796.jpg
#   inflating: ./dogcat/train/dog.5797.jpg
#   inflating: ./dogcat/train/dog.5798.jpg
#   inflating: ./dogcat/train/dog.5799.jpg
#   inflating: ./dogcat/train/dog.58.jpg
#   inflating: ./dogcat/train/dog.580.jpg
#   inflating: ./dogcat/train/dog.5800.jpg
#   inflating: ./dogcat/train/dog.5801.jpg
#   inflating: ./dogcat/train/dog.5802.jpg
#   inflating: ./dogcat/train/dog.5803.jpg
#   inflating: ./dogcat/train/dog.5804.jpg
#   inflating: ./dogcat/train/dog.5805.jpg
#   inflating: ./dogcat/train/dog.5806.jpg
#   inflating: ./dogcat/train/dog.5807.jpg
#   inflating: ./dogcat/train/dog.5808.jpg
#   inflating: ./dogcat/train/dog.5809.jpg
#   inflating: ./dogcat/train/dog.581.jpg
#   inflating: ./dogcat/train/dog.5810.jpg
#   inflating: ./dogcat/train/dog.5811.jpg
#   inflating: ./dogcat/train/dog.5812.jpg
#   inflating: ./dogcat/train/dog.5813.jpg
#   inflating: ./dogcat/train/dog.5814.jpg
#   inflating: ./dogcat/train/dog.5815.jpg
#   inflating: ./dogcat/train/dog.5816.jpg
#   inflating: ./dogcat/train/dog.5817.jpg
#   inflating: ./dogcat/train/dog.5818.jpg
#   inflating: ./dogcat/train/dog.5819.jpg
#   inflating: ./dogcat/train/dog.582.jpg
#   inflating: ./dogcat/train/dog.5820.jpg
#   inflating: ./dogcat/train/dog.5821.jpg
#   inflating: ./dogcat/train/dog.5822.jpg
#   inflating: ./dogcat/train/dog.5823.jpg
#   inflating: ./dogcat/train/dog.5824.jpg
#   inflating: ./dogcat/train/dog.5825.jpg
#   inflating: ./dogcat/train/dog.5826.jpg
#   inflating: ./dogcat/train/dog.5827.jpg
#   inflating: ./dogcat/train/dog.5828.jpg
#   inflating: ./dogcat/train/dog.5829.jpg
#   inflating: ./dogcat/train/dog.583.jpg
#   inflating: ./dogcat/train/dog.5830.jpg
#   inflating: ./dogcat/train/dog.5831.jpg
#   inflating: ./dogcat/train/dog.5832.jpg
#   inflating: ./dogcat/train/dog.5833.jpg
#   inflating: ./dogcat/train/dog.5834.jpg
#   inflating: ./dogcat/train/dog.5835.jpg
#   inflating: ./dogcat/train/dog.5836.jpg
#   inflating: ./dogcat/train/dog.5837.jpg
#   inflating: ./dogcat/train/dog.5838.jpg
#   inflating: ./dogcat/train/dog.5839.jpg
#   inflating: ./dogcat/train/dog.584.jpg
#   inflating: ./dogcat/train/dog.5840.jpg
#   inflating: ./dogcat/train/dog.5841.jpg
#   inflating: ./dogcat/train/dog.5842.jpg
#   inflating: ./dogcat/train/dog.5843.jpg
#   inflating: ./dogcat/train/dog.5844.jpg
#   inflating: ./dogcat/train/dog.5845.jpg
#   inflating: ./dogcat/train/dog.5846.jpg
#   inflating: ./dogcat/train/dog.5847.jpg
#   inflating: ./dogcat/train/dog.5848.jpg
#   inflating: ./dogcat/train/dog.5849.jpg
#   inflating: ./dogcat/train/dog.585.jpg
#   inflating: ./dogcat/train/dog.5850.jpg
#   inflating: ./dogcat/train/dog.5851.jpg
#   inflating: ./dogcat/train/dog.5852.jpg
#   inflating: ./dogcat/train/dog.5853.jpg
#   inflating: ./dogcat/train/dog.5854.jpg
#   inflating: ./dogcat/train/dog.5855.jpg
#   inflating: ./dogcat/train/dog.5856.jpg
#   inflating: ./dogcat/train/dog.5857.jpg
#   inflating: ./dogcat/train/dog.5858.jpg
#   inflating: ./dogcat/train/dog.5859.jpg
#   inflating: ./dogcat/train/dog.586.jpg
#   inflating: ./dogcat/train/dog.5860.jpg
#   inflating: ./dogcat/train/dog.5861.jpg
#   inflating: ./dogcat/train/dog.5862.jpg
#   inflating: ./dogcat/train/dog.5863.jpg
#   inflating: ./dogcat/train/dog.5864.jpg
#   inflating: ./dogcat/train/dog.5865.jpg
#   inflating: ./dogcat/train/dog.5866.jpg
#   inflating: ./dogcat/train/dog.5867.jpg
#   inflating: ./dogcat/train/dog.5868.jpg
#   inflating: ./dogcat/train/dog.5869.jpg
#   inflating: ./dogcat/train/dog.587.jpg
#   inflating: ./dogcat/train/dog.5870.jpg
#   inflating: ./dogcat/train/dog.5871.jpg
#   inflating: ./dogcat/train/dog.5872.jpg
#   inflating: ./dogcat/train/dog.5873.jpg
#   inflating: ./dogcat/train/dog.5874.jpg
#   inflating: ./dogcat/train/dog.5875.jpg
#   inflating: ./dogcat/train/dog.5876.jpg
#   inflating: ./dogcat/train/dog.5877.jpg
#   inflating: ./dogcat/train/dog.5878.jpg
#   inflating: ./dogcat/train/dog.5879.jpg
#   inflating: ./dogcat/train/dog.588.jpg
#   inflating: ./dogcat/train/dog.5880.jpg
#   inflating: ./dogcat/train/dog.5881.jpg
#   inflating: ./dogcat/train/dog.5882.jpg
#   inflating: ./dogcat/train/dog.5883.jpg
#   inflating: ./dogcat/train/dog.5884.jpg
#   inflating: ./dogcat/train/dog.5885.jpg
#   inflating: ./dogcat/train/dog.5886.jpg
#   inflating: ./dogcat/train/dog.5887.jpg
#   inflating: ./dogcat/train/dog.5888.jpg
#   inflating: ./dogcat/train/dog.5889.jpg
#   inflating: ./dogcat/train/dog.589.jpg
#   inflating: ./dogcat/train/dog.5890.jpg
#   inflating: ./dogcat/train/dog.5891.jpg
#   inflating: ./dogcat/train/dog.5892.jpg
#   inflating: ./dogcat/train/dog.5893.jpg
#   inflating: ./dogcat/train/dog.5894.jpg
#   inflating: ./dogcat/train/dog.5895.jpg
#   inflating: ./dogcat/train/dog.5896.jpg
#   inflating: ./dogcat/train/dog.5897.jpg
#   inflating: ./dogcat/train/dog.5898.jpg
#   inflating: ./dogcat/train/dog.5899.jpg
#   inflating: ./dogcat/train/dog.59.jpg
#   inflating: ./dogcat/train/dog.590.jpg
#   inflating: ./dogcat/train/dog.5900.jpg
#   inflating: ./dogcat/train/dog.5901.jpg
#   inflating: ./dogcat/train/dog.5902.jpg
#   inflating: ./dogcat/train/dog.5903.jpg
#   inflating: ./dogcat/train/dog.5904.jpg
#   inflating: ./dogcat/train/dog.5905.jpg
#   inflating: ./dogcat/train/dog.5906.jpg
#   inflating: ./dogcat/train/dog.5907.jpg
#   inflating: ./dogcat/train/dog.5908.jpg
#   inflating: ./dogcat/train/dog.5909.jpg
#   inflating: ./dogcat/train/dog.591.jpg
#   inflating: ./dogcat/train/dog.5910.jpg
#   inflating: ./dogcat/train/dog.5911.jpg
#   inflating: ./dogcat/train/dog.5912.jpg
#   inflating: ./dogcat/train/dog.5913.jpg
#   inflating: ./dogcat/train/dog.5914.jpg
#   inflating: ./dogcat/train/dog.5915.jpg
#   inflating: ./dogcat/train/dog.5916.jpg
#   inflating: ./dogcat/train/dog.5917.jpg
#   inflating: ./dogcat/train/dog.5918.jpg
#   inflating: ./dogcat/train/dog.5919.jpg
#   inflating: ./dogcat/train/dog.592.jpg
#   inflating: ./dogcat/train/dog.5920.jpg
#   inflating: ./dogcat/train/dog.5921.jpg
#   inflating: ./dogcat/train/dog.5922.jpg
#   inflating: ./dogcat/train/dog.5923.jpg
#   inflating: ./dogcat/train/dog.5924.jpg
#   inflating: ./dogcat/train/dog.5925.jpg
#   inflating: ./dogcat/train/dog.5926.jpg
#   inflating: ./dogcat/train/dog.5927.jpg
#   inflating: ./dogcat/train/dog.5928.jpg
#   inflating: ./dogcat/train/dog.5929.jpg
#   inflating: ./dogcat/train/dog.593.jpg
#   inflating: ./dogcat/train/dog.5930.jpg
#   inflating: ./dogcat/train/dog.5931.jpg
#   inflating: ./dogcat/train/dog.5932.jpg
#   inflating: ./dogcat/train/dog.5933.jpg
#   inflating: ./dogcat/train/dog.5934.jpg
#   inflating: ./dogcat/train/dog.5935.jpg
#   inflating: ./dogcat/train/dog.5936.jpg
#   inflating: ./dogcat/train/dog.5937.jpg
#   inflating: ./dogcat/train/dog.5938.jpg
#   inflating: ./dogcat/train/dog.5939.jpg
#   inflating: ./dogcat/train/dog.594.jpg
#   inflating: ./dogcat/train/dog.5940.jpg
#   inflating: ./dogcat/train/dog.5941.jpg
#   inflating: ./dogcat/train/dog.5942.jpg
#   inflating: ./dogcat/train/dog.5943.jpg
#   inflating: ./dogcat/train/dog.5944.jpg
#   inflating: ./dogcat/train/dog.5945.jpg
#   inflating: ./dogcat/train/dog.5946.jpg
#   inflating: ./dogcat/train/dog.5947.jpg
#   inflating: ./dogcat/train/dog.5948.jpg
#   inflating: ./dogcat/train/dog.5949.jpg
#   inflating: ./dogcat/train/dog.595.jpg
#   inflating: ./dogcat/train/dog.5950.jpg
#   inflating: ./dogcat/train/dog.5951.jpg
#   inflating: ./dogcat/train/dog.5952.jpg
#   inflating: ./dogcat/train/dog.5953.jpg
#   inflating: ./dogcat/train/dog.5954.jpg
#   inflating: ./dogcat/train/dog.5955.jpg
#   inflating: ./dogcat/train/dog.5956.jpg
#   inflating: ./dogcat/train/dog.5957.jpg
#   inflating: ./dogcat/train/dog.5958.jpg
#   inflating: ./dogcat/train/dog.5959.jpg
#   inflating: ./dogcat/train/dog.596.jpg
#   inflating: ./dogcat/train/dog.5960.jpg
#   inflating: ./dogcat/train/dog.5961.jpg
#   inflating: ./dogcat/train/dog.5962.jpg
#   inflating: ./dogcat/train/dog.5963.jpg
#   inflating: ./dogcat/train/dog.5964.jpg
#   inflating: ./dogcat/train/dog.5965.jpg
#   inflating: ./dogcat/train/dog.5966.jpg
#   inflating: ./dogcat/train/dog.5967.jpg
#   inflating: ./dogcat/train/dog.5968.jpg
#   inflating: ./dogcat/train/dog.5969.jpg
#   inflating: ./dogcat/train/dog.597.jpg
#   inflating: ./dogcat/train/dog.5970.jpg
#   inflating: ./dogcat/train/dog.5971.jpg
#   inflating: ./dogcat/train/dog.5972.jpg
#   inflating: ./dogcat/train/dog.5973.jpg
#   inflating: ./dogcat/train/dog.5974.jpg
#   inflating: ./dogcat/train/dog.5975.jpg
#   inflating: ./dogcat/train/dog.5976.jpg
#   inflating: ./dogcat/train/dog.5977.jpg
#   inflating: ./dogcat/train/dog.5978.jpg
#   inflating: ./dogcat/train/dog.5979.jpg
#   inflating: ./dogcat/train/dog.598.jpg
#   inflating: ./dogcat/train/dog.5980.jpg
#   inflating: ./dogcat/train/dog.5981.jpg
#   inflating: ./dogcat/train/dog.5982.jpg
#   inflating: ./dogcat/train/dog.5983.jpg
#   inflating: ./dogcat/train/dog.5984.jpg
#   inflating: ./dogcat/train/dog.5985.jpg
#   inflating: ./dogcat/train/dog.5986.jpg
#   inflating: ./dogcat/train/dog.5987.jpg
#   inflating: ./dogcat/train/dog.5988.jpg
#   inflating: ./dogcat/train/dog.5989.jpg
#   inflating: ./dogcat/train/dog.599.jpg
#   inflating: ./dogcat/train/dog.5990.jpg
#   inflating: ./dogcat/train/dog.5991.jpg
#   inflating: ./dogcat/train/dog.5992.jpg
#   inflating: ./dogcat/train/dog.5993.jpg
#   inflating: ./dogcat/train/dog.5994.jpg
#   inflating: ./dogcat/train/dog.5995.jpg
#   inflating: ./dogcat/train/dog.5996.jpg
#   inflating: ./dogcat/train/dog.5997.jpg
#   inflating: ./dogcat/train/dog.5998.jpg
#   inflating: ./dogcat/train/dog.5999.jpg
#   inflating: ./dogcat/train/dog.6.jpg
#   inflating: ./dogcat/train/dog.60.jpg
#   inflating: ./dogcat/train/dog.600.jpg
#   inflating: ./dogcat/train/dog.6000.jpg
#   inflating: ./dogcat/train/dog.6001.jpg
#   inflating: ./dogcat/train/dog.6002.jpg
#   inflating: ./dogcat/train/dog.6003.jpg
#   inflating: ./dogcat/train/dog.6004.jpg
#   inflating: ./dogcat/train/dog.6005.jpg
#   inflating: ./dogcat/train/dog.6006.jpg
#   inflating: ./dogcat/train/dog.6007.jpg
#   inflating: ./dogcat/train/dog.6008.jpg
#   inflating: ./dogcat/train/dog.6009.jpg
#   inflating: ./dogcat/train/dog.601.jpg
#   inflating: ./dogcat/train/dog.6010.jpg
#   inflating: ./dogcat/train/dog.6011.jpg
#   inflating: ./dogcat/train/dog.6012.jpg
#   inflating: ./dogcat/train/dog.6013.jpg
#   inflating: ./dogcat/train/dog.6014.jpg
#   inflating: ./dogcat/train/dog.6015.jpg
#   inflating: ./dogcat/train/dog.6016.jpg
#   inflating: ./dogcat/train/dog.6017.jpg
#   inflating: ./dogcat/train/dog.6018.jpg
#   inflating: ./dogcat/train/dog.6019.jpg
#   inflating: ./dogcat/train/dog.602.jpg
#   inflating: ./dogcat/train/dog.6020.jpg
#   inflating: ./dogcat/train/dog.6021.jpg
#   inflating: ./dogcat/train/dog.6022.jpg
#   inflating: ./dogcat/train/dog.6023.jpg
#   inflating: ./dogcat/train/dog.6024.jpg
#   inflating: ./dogcat/train/dog.6025.jpg
#   inflating: ./dogcat/train/dog.6026.jpg
#   inflating: ./dogcat/train/dog.6466.jpg
#   inflating: ./dogcat/train/dog.6467.jpg
#   inflating: ./dogcat/train/dog.6468.jpg
#   inflating: ./dogcat/train/dog.6469.jpg
#   inflating: ./dogcat/train/dog.647.jpg
#   inflating: ./dogcat/train/dog.6470.jpg
#   inflating: ./dogcat/train/dog.6471.jpg
#   inflating: ./dogcat/train/dog.6472.jpg
#   inflating: ./dogcat/train/dog.6473.jpg
#   inflating: ./dogcat/train/dog.6474.jpg
#   inflating: ./dogcat/train/dog.6475.jpg
#   inflating: ./dogcat/train/dog.6476.jpg
#   inflating: ./dogcat/train/dog.6477.jpg
#   inflating: ./dogcat/train/dog.6478.jpg
#   inflating: ./dogcat/train/dog.6479.jpg
#   inflating: ./dogcat/train/dog.648.jpg
#   inflating: ./dogcat/train/dog.6480.jpg
#   inflating: ./dogcat/train/dog.6481.jpg
#   inflating: ./dogcat/train/dog.6482.jpg
#   inflating: ./dogcat/train/dog.6483.jpg
#   inflating: ./dogcat/train/dog.6484.jpg
#   inflating: ./dogcat/train/dog.6485.jpg
#   inflating: ./dogcat/train/dog.6486.jpg
#   inflating: ./dogcat/train/dog.6487.jpg
#   inflating: ./dogcat/train/dog.6488.jpg
#   inflating: ./dogcat/train/dog.6489.jpg
#   inflating: ./dogcat/train/dog.649.jpg
#   inflating: ./dogcat/train/dog.6490.jpg
#   inflating: ./dogcat/train/dog.6491.jpg
#   inflating: ./dogcat/train/dog.6492.jpg
#   inflating: ./dogcat/train/dog.6493.jpg
#   inflating: ./dogcat/train/dog.6494.jpg
#   inflating: ./dogcat/train/dog.6495.jpg
#   inflating: ./dogcat/train/dog.6496.jpg
#   inflating: ./dogcat/train/dog.6497.jpg
#   inflating: ./dogcat/train/dog.6498.jpg
#   inflating: ./dogcat/train/dog.6499.jpg
#   inflating: ./dogcat/train/dog.65.jpg
#   inflating: ./dogcat/train/dog.650.jpg
#   inflating: ./dogcat/train/dog.6500.jpg
#   inflating: ./dogcat/train/dog.6501.jpg
#   inflating: ./dogcat/train/dog.6502.jpg
#   inflating: ./dogcat/train/dog.6503.jpg
# ...
#   inflating: ./dogcat/train/dog.9663.jpg
#   inflating: ./dogcat/train/dog.9664.jpg
#   inflating: ./dogcat/train/dog.9665.jpg
#   inflating: ./dogcat/train/dog.9666.jpg
#   inflating: ./dogcat/train/dog.9667.jpg
#   inflating: ./dogcat/train/dog.9668.jpg
#   inflating: ./dogcat/train/dog.9669.jpg
#   inflating: ./dogcat/train/dog.967.jpg
#   inflating: ./dogcat/train/dog.9670.jpg
#   inflating: ./dogcat/train/dog.9671.jpg
#   inflating: ./dogcat/train/dog.9672.jpg
#   inflating: ./dogcat/train/dog.9673.jpg
#   inflating: ./dogcat/train/dog.9674.jpg
#   inflating: ./dogcat/train/dog.9675.jpg
#   inflating: ./dogcat/train/dog.9676.jpg
#   inflating: ./dogcat/train/dog.9677.jpg
#   inflating: ./dogcat/train/dog.9678.jpg
#   inflating: ./dogcat/train/dog.9679.jpg
#   inflating: ./dogcat/train/dog.968.jpg
#   inflating: ./dogcat/train/dog.9680.jpg
#   inflating: ./dogcat/train/dog.9681.jpg
#   inflating: ./dogcat/train/dog.9682.jpg
#   inflating: ./dogcat/train/dog.9683.jpg
#   inflating: ./dogcat/train/dog.9684.jpg
#   inflating: ./dogcat/train/dog.9685.jpg
#   inflating: ./dogcat/train/dog.9686.jpg
#   inflating: ./dogcat/train/dog.9687.jpg
#   inflating: ./dogcat/train/dog.9688.jpg
#   inflating: ./dogcat/train/dog.9689.jpg
#   inflating: ./dogcat/train/dog.969.jpg
#   inflating: ./dogcat/train/dog.9690.jpg
#   inflating: ./dogcat/train/dog.9691.jpg
#   inflating: ./dogcat/train/dog.9692.jpg
#   inflating: ./dogcat/train/dog.9693.jpg
#   inflating: ./dogcat/train/dog.9694.jpg
#   inflating: ./dogcat/train/dog.9695.jpg
#   inflating: ./dogcat/train/dog.9696.jpg
#   inflating: ./dogcat/train/dog.9697.jpg
#   inflating: ./dogcat/train/dog.9698.jpg
#   inflating: ./dogcat/train/dog.9699.jpg
#   inflating: ./dogcat/train/dog.97.jpg
#   inflating: ./dogcat/train/dog.970.jpg
#   inflating: ./dogcat/train/dog.9700.jpg
#   inflating: ./dogcat/train/dog.9701.jpg
#   inflating: ./dogcat/train/dog.9702.jpg
#   inflating: ./dogcat/train/dog.9703.jpg
#   inflating: ./dogcat/train/dog.9704.jpg
#   inflating: ./dogcat/train/dog.9705.jpg
#   inflating: ./dogcat/train/dog.9706.jpg
#   inflating: ./dogcat/train/dog.9707.jpg
#   inflating: ./dogcat/train/dog.9708.jpg
#   inflating: ./dogcat/train/dog.9709.jpg
#   inflating: ./dogcat/train/dog.971.jpg
#   inflating: ./dogcat/train/dog.9710.jpg
#   inflating: ./dogcat/train/dog.9711.jpg
#   inflating: ./dogcat/train/dog.9712.jpg
#   inflating: ./dogcat/train/dog.9713.jpg
#   inflating: ./dogcat/train/dog.9714.jpg
#   inflating: ./dogcat/train/dog.9715.jpg
#   inflating: ./dogcat/train/dog.9716.jpg
#   inflating: ./dogcat/train/dog.9717.jpg
#   inflating: ./dogcat/train/dog.9718.jpg
#   inflating: ./dogcat/train/dog.9719.jpg
#   inflating: ./dogcat/train/dog.972.jpg
#   inflating: ./dogcat/train/dog.9720.jpg
#   inflating: ./dogcat/train/dog.9721.jpg
#   inflating: ./dogcat/train/dog.9722.jpg
#   inflating: ./dogcat/train/dog.9723.jpg
#   inflating: ./dogcat/train/dog.9724.jpg
#   inflating: ./dogcat/train/dog.9725.jpg
#   inflating: ./dogcat/train/dog.9726.jpg
#   inflating: ./dogcat/train/dog.9727.jpg
#   inflating: ./dogcat/train/dog.9728.jpg
#   inflating: ./dogcat/train/dog.9729.jpg
#   inflating: ./dogcat/train/dog.973.jpg
#   inflating: ./dogcat/train/dog.9730.jpg
#   inflating: ./dogcat/train/dog.9731.jpg
#   inflating: ./dogcat/train/dog.9732.jpg
#   inflating: ./dogcat/train/dog.9733.jpg
#   inflating: ./dogcat/train/dog.9734.jpg
#   inflating: ./dogcat/train/dog.9735.jpg
#   inflating: ./dogcat/train/dog.9736.jpg
#   inflating: ./dogcat/train/dog.9737.jpg
#   inflating: ./dogcat/train/dog.9738.jpg
#   inflating: ./dogcat/train/dog.9739.jpg
#   inflating: ./dogcat/train/dog.974.jpg
#   inflating: ./dogcat/train/dog.9740.jpg
#   inflating: ./dogcat/train/dog.9741.jpg
#   inflating: ./dogcat/train/dog.9742.jpg
#   inflating: ./dogcat/train/dog.9743.jpg
#   inflating: ./dogcat/train/dog.9744.jpg
#   inflating: ./dogcat/train/dog.9745.jpg
#   inflating: ./dogcat/train/dog.9746.jpg
#   inflating: ./dogcat/train/dog.9747.jpg
#   inflating: ./dogcat/train/dog.9748.jpg
#   inflating: ./dogcat/train/dog.9749.jpg
#   inflating: ./dogcat/train/dog.975.jpg
#   inflating: ./dogcat/train/dog.9750.jpg
#   inflating: ./dogcat/train/dog.9751.jpg
#   inflating: ./dogcat/train/dog.9752.jpg
#   inflating: ./dogcat/train/dog.9753.jpg
#   inflating: ./dogcat/train/dog.9754.jpg
#   inflating: ./dogcat/train/dog.9755.jpg
#   inflating: ./dogcat/train/dog.9756.jpg
#   inflating: ./dogcat/train/dog.9757.jpg
#   inflating: ./dogcat/train/dog.9758.jpg
#   inflating: ./dogcat/train/dog.9759.jpg
#   inflating: ./dogcat/train/dog.976.jpg
#   inflating: ./dogcat/train/dog.9760.jpg
#   inflating: ./dogcat/train/dog.9761.jpg
#   inflating: ./dogcat/train/dog.9762.jpg
#   inflating: ./dogcat/train/dog.9763.jpg
#   inflating: ./dogcat/train/dog.9764.jpg
#   inflating: ./dogcat/train/dog.9765.jpg
#   inflating: ./dogcat/train/dog.9766.jpg
#   inflating: ./dogcat/train/dog.9767.jpg
#   inflating: ./dogcat/train/dog.9768.jpg
#   inflating: ./dogcat/train/dog.9769.jpg
#   inflating: ./dogcat/train/dog.977.jpg
#   inflating: ./dogcat/train/dog.9770.jpg
#   inflating: ./dogcat/train/dog.9771.jpg
#   inflating: ./dogcat/train/dog.9772.jpg
#   inflating: ./dogcat/train/dog.9773.jpg
#   inflating: ./dogcat/train/dog.9774.jpg
#   inflating: ./dogcat/train/dog.9775.jpg
#   inflating: ./dogcat/train/dog.9776.jpg
#   inflating: ./dogcat/train/dog.9777.jpg
#   inflating: ./dogcat/train/dog.9778.jpg
#   inflating: ./dogcat/train/dog.9779.jpg
#   inflating: ./dogcat/train/dog.978.jpg
#   inflating: ./dogcat/train/dog.9780.jpg
#   inflating: ./dogcat/train/dog.9781.jpg
#   inflating: ./dogcat/train/dog.9782.jpg
#   inflating: ./dogcat/train/dog.9783.jpg
#   inflating: ./dogcat/train/dog.9784.jpg
#   inflating: ./dogcat/train/dog.9785.jpg
#   inflating: ./dogcat/train/dog.9786.jpg
#   inflating: ./dogcat/train/dog.9787.jpg
#   inflating: ./dogcat/train/dog.9788.jpg
#   inflating: ./dogcat/train/dog.9789.jpg
#   inflating: ./dogcat/train/dog.979.jpg
#   inflating: ./dogcat/train/dog.9790.jpg
#   inflating: ./dogcat/train/dog.9791.jpg
#   inflating: ./dogcat/train/dog.9792.jpg
#   inflating: ./dogcat/train/dog.9793.jpg
#   inflating: ./dogcat/train/dog.9794.jpg
#   inflating: ./dogcat/train/dog.9795.jpg
#   inflating: ./dogcat/train/dog.9796.jpg
#   inflating: ./dogcat/train/dog.9797.jpg
#   inflating: ./dogcat/train/dog.9798.jpg
#   inflating: ./dogcat/train/dog.9799.jpg
#   inflating: ./dogcat/train/dog.98.jpg
#   inflating: ./dogcat/train/dog.980.jpg
#   inflating: ./dogcat/train/dog.9800.jpg
#   inflating: ./dogcat/train/dog.9801.jpg
#   inflating: ./dogcat/train/dog.9802.jpg
#   inflating: ./dogcat/train/dog.9803.jpg
#   inflating: ./dogcat/train/dog.9804.jpg
#   inflating: ./dogcat/train/dog.9805.jpg
#   inflating: ./dogcat/train/dog.9806.jpg
#   inflating: ./dogcat/train/dog.9807.jpg
#   inflating: ./dogcat/train/dog.9808.jpg
#   inflating: ./dogcat/train/dog.9809.jpg
#   inflating: ./dogcat/train/dog.981.jpg
#   inflating: ./dogcat/train/dog.9810.jpg
#   inflating: ./dogcat/train/dog.9811.jpg
#   inflating: ./dogcat/train/dog.9812.jpg
#   inflating: ./dogcat/train/dog.9813.jpg
#   inflating: ./dogcat/train/dog.9814.jpg
#   inflating: ./dogcat/train/dog.9815.jpg
#   inflating: ./dogcat/train/dog.9816.jpg
#   inflating: ./dogcat/train/dog.9817.jpg
#   inflating: ./dogcat/train/dog.9818.jpg
#   inflating: ./dogcat/train/dog.9819.jpg
#   inflating: ./dogcat/train/dog.982.jpg
#   inflating: ./dogcat/train/dog.9820.jpg
#   inflating: ./dogcat/train/dog.9821.jpg
#   inflating: ./dogcat/train/dog.9822.jpg
#   inflating: ./dogcat/train/dog.9823.jpg
#   inflating: ./dogcat/train/dog.9824.jpg
#   inflating: ./dogcat/train/dog.9825.jpg
#   inflating: ./dogcat/train/dog.9826.jpg
#   inflating: ./dogcat/train/dog.9827.jpg
#   inflating: ./dogcat/train/dog.9828.jpg
#   inflating: ./dogcat/train/dog.9829.jpg
#   inflating: ./dogcat/train/dog.983.jpg
#   inflating: ./dogcat/train/dog.9830.jpg
#   inflating: ./dogcat/train/dog.9831.jpg
#   inflating: ./dogcat/train/dog.9832.jpg
#   inflating: ./dogcat/train/dog.9833.jpg
#   inflating: ./dogcat/train/dog.9834.jpg
#   inflating: ./dogcat/train/dog.9835.jpg
#   inflating: ./dogcat/train/dog.9836.jpg
#   inflating: ./dogcat/train/dog.9837.jpg
#   inflating: ./dogcat/train/dog.9838.jpg
#   inflating: ./dogcat/train/dog.9839.jpg
#   inflating: ./dogcat/train/dog.984.jpg
#   inflating: ./dogcat/train/dog.9840.jpg
#   inflating: ./dogcat/train/dog.9841.jpg
#   inflating: ./dogcat/train/dog.9842.jpg
#   inflating: ./dogcat/train/dog.9843.jpg
#   inflating: ./dogcat/train/dog.9844.jpg
#   inflating: ./dogcat/train/dog.9845.jpg
#   inflating: ./dogcat/train/dog.9846.jpg
#   inflating: ./dogcat/train/dog.9847.jpg
#   inflating: ./dogcat/train/dog.9848.jpg
#   inflating: ./dogcat/train/dog.9849.jpg
#   inflating: ./dogcat/train/dog.985.jpg
#   inflating: ./dogcat/train/dog.9850.jpg
#   inflating: ./dogcat/train/dog.9851.jpg
#   inflating: ./dogcat/train/dog.9852.jpg
#   inflating: ./dogcat/train/dog.9853.jpg
#   inflating: ./dogcat/train/dog.9854.jpg
#   inflating: ./dogcat/train/dog.9855.jpg
#   inflating: ./dogcat/train/dog.9856.jpg
#   inflating: ./dogcat/train/dog.9857.jpg
#   inflating: ./dogcat/train/dog.9858.jpg
#   inflating: ./dogcat/train/dog.9859.jpg
#   inflating: ./dogcat/train/dog.986.jpg
#   inflating: ./dogcat/train/dog.9860.jpg
#   inflating: ./dogcat/train/dog.9861.jpg
#   inflating: ./dogcat/train/dog.9862.jpg
#   inflating: ./dogcat/train/dog.9863.jpg
#   inflating: ./dogcat/train/dog.9864.jpg
#   inflating: ./dogcat/train/dog.9865.jpg
#   inflating: ./dogcat/train/dog.9866.jpg
#   inflating: ./dogcat/train/dog.9867.jpg
#   inflating: ./dogcat/train/dog.9868.jpg
#   inflating: ./dogcat/train/dog.9869.jpg
#   inflating: ./dogcat/train/dog.987.jpg
#   inflating: ./dogcat/train/dog.9870.jpg
#   inflating: ./dogcat/train/dog.9871.jpg
#   inflating: ./dogcat/train/dog.9872.jpg
#   inflating: ./dogcat/train/dog.9873.jpg
#   inflating: ./dogcat/train/dog.9874.jpg
#   inflating: ./dogcat/train/dog.9875.jpg
#   inflating: ./dogcat/train/dog.9876.jpg
#   inflating: ./dogcat/train/dog.9877.jpg
#   inflating: ./dogcat/train/dog.9878.jpg
#   inflating: ./dogcat/train/dog.9879.jpg
#   inflating: ./dogcat/train/dog.988.jpg
#   inflating: ./dogcat/train/dog.9880.jpg
#   inflating: ./dogcat/train/dog.9881.jpg
#   inflating: ./dogcat/train/dog.9882.jpg
#   inflating: ./dogcat/train/dog.9883.jpg
#   inflating: ./dogcat/train/dog.9884.jpg
#   inflating: ./dogcat/train/dog.9885.jpg
#   inflating: ./dogcat/train/dog.9886.jpg
#   inflating: ./dogcat/train/dog.9887.jpg
#   inflating: ./dogcat/train/dog.9888.jpg
#   inflating: ./dogcat/train/dog.9889.jpg
#   inflating: ./dogcat/train/dog.989.jpg
#   inflating: ./dogcat/train/dog.9890.jpg
#   inflating: ./dogcat/train/dog.9891.jpg
#   inflating: ./dogcat/train/dog.9892.jpg
#   inflating: ./dogcat/train/dog.9893.jpg
#   inflating: ./dogcat/train/dog.9894.jpg
#   inflating: ./dogcat/train/dog.9895.jpg
#   inflating: ./dogcat/train/dog.9896.jpg
#   inflating: ./dogcat/train/dog.9897.jpg
#   inflating: ./dogcat/train/dog.9898.jpg
#   inflating: ./dogcat/train/dog.9899.jpg
#   inflating: ./dogcat/train/dog.99.jpg
#   inflating: ./dogcat/train/dog.990.jpg
#   inflating: ./dogcat/train/dog.9900.jpg
#   inflating: ./dogcat/train/dog.9901.jpg
#   inflating: ./dogcat/train/dog.9902.jpg
#   inflating: ./dogcat/train/dog.9903.jpg
#   inflating: ./dogcat/train/dog.9904.jpg
#   inflating: ./dogcat/train/dog.9905.jpg
#   inflating: ./dogcat/train/dog.9906.jpg
#   inflating: ./dogcat/train/dog.9907.jpg
#   inflating: ./dogcat/train/dog.9908.jpg
#   inflating: ./dogcat/train/dog.9909.jpg
#   inflating: ./dogcat/train/dog.991.jpg
#   inflating: ./dogcat/train/dog.9910.jpg
#   inflating: ./dogcat/train/dog.9911.jpg
#   inflating: ./dogcat/train/dog.9912.jpg
#   inflating: ./dogcat/train/dog.9913.jpg
#   inflating: ./dogcat/train/dog.9914.jpg
#   inflating: ./dogcat/train/dog.9915.jpg
#   inflating: ./dogcat/train/dog.9916.jpg
#   inflating: ./dogcat/train/dog.9917.jpg
#   inflating: ./dogcat/train/dog.9918.jpg
#   inflating: ./dogcat/train/dog.9919.jpg
#   inflating: ./dogcat/train/dog.992.jpg
#   inflating: ./dogcat/train/dog.9920.jpg
#   inflating: ./dogcat/train/dog.9921.jpg
#   inflating: ./dogcat/train/dog.9922.jpg
#   inflating: ./dogcat/train/dog.9923.jpg
#   inflating: ./dogcat/train/dog.9924.jpg
#   inflating: ./dogcat/train/dog.9925.jpg
#   inflating: ./dogcat/train/dog.9926.jpg
#   inflating: ./dogcat/train/dog.9927.jpg
#   inflating: ./dogcat/train/dog.9928.jpg
#   inflating: ./dogcat/train/dog.9929.jpg
#   inflating: ./dogcat/train/dog.993.jpg
#   inflating: ./dogcat/train/dog.9930.jpg
#   inflating: ./dogcat/train/dog.9931.jpg
#   inflating: ./dogcat/train/dog.9932.jpg
#   inflating: ./dogcat/train/dog.9933.jpg
#   inflating: ./dogcat/train/dog.9934.jpg
#   inflating: ./dogcat/train/dog.9935.jpg
#   inflating: ./dogcat/train/dog.9936.jpg
#   inflating: ./dogcat/train/dog.9937.jpg
#   inflating: ./dogcat/train/dog.9938.jpg
#   inflating: ./dogcat/train/dog.9939.jpg
#   inflating: ./dogcat/train/dog.994.jpg
#   inflating: ./dogcat/train/dog.9940.jpg
#   inflating: ./dogcat/train/dog.9941.jpg
#   inflating: ./dogcat/train/dog.9942.jpg
#   inflating: ./dogcat/train/dog.9943.jpg
#   inflating: ./dogcat/train/dog.9944.jpg
#   inflating: ./dogcat/train/dog.9945.jpg
#   inflating: ./dogcat/train/dog.9946.jpg
#   inflating: ./dogcat/train/dog.9947.jpg
#   inflating: ./dogcat/train/dog.9948.jpg
#   inflating: ./dogcat/train/dog.9949.jpg
#   inflating: ./dogcat/train/dog.995.jpg
#   inflating: ./dogcat/train/dog.9950.jpg
#   inflating: ./dogcat/train/dog.9951.jpg
#   inflating: ./dogcat/train/dog.9952.jpg
#   inflating: ./dogcat/train/dog.9953.jpg
#   inflating: ./dogcat/train/dog.9954.jpg
#   inflating: ./dogcat/train/dog.9955.jpg
#   inflating: ./dogcat/train/dog.9956.jpg
#   inflating: ./dogcat/train/dog.9957.jpg
#   inflating: ./dogcat/train/dog.9958.jpg
#   inflating: ./dogcat/train/dog.9959.jpg
#   inflating: ./dogcat/train/dog.996.jpg
#   inflating: ./dogcat/train/dog.9960.jpg
#   inflating: ./dogcat/train/dog.9961.jpg
#   inflating: ./dogcat/train/dog.9962.jpg
#   inflating: ./dogcat/train/dog.9963.jpg
#   inflating: ./dogcat/train/dog.9964.jpg
#   inflating: ./dogcat/train/dog.9965.jpg
#   inflating: ./dogcat/train/dog.9966.jpg
#   inflating: ./dogcat/train/dog.9967.jpg
#   inflating: ./dogcat/train/dog.9968.jpg
#   inflating: ./dogcat/train/dog.9969.jpg
#   inflating: ./dogcat/train/dog.997.jpg
#   inflating: ./dogcat/train/dog.9970.jpg
#   inflating: ./dogcat/train/dog.9971.jpg
#   inflating: ./dogcat/train/dog.9972.jpg
#   inflating: ./dogcat/train/dog.9973.jpg
#   inflating: ./dogcat/train/dog.9974.jpg
#   inflating: ./dogcat/train/dog.9975.jpg
#   inflating: ./dogcat/train/dog.9976.jpg
#   inflating: ./dogcat/train/dog.9977.jpg
#   inflating: ./dogcat/train/dog.9978.jpg
#   inflating: ./dogcat/train/dog.9979.jpg
#   inflating: ./dogcat/train/dog.998.jpg
#   inflating: ./dogcat/train/dog.9980.jpg
#   inflating: ./dogcat/train/dog.9981.jpg
#   inflating: ./dogcat/train/dog.9982.jpg
#   inflating: ./dogcat/train/dog.9983.jpg
#   inflating: ./dogcat/train/dog.9984.jpg
#   inflating: ./dogcat/train/dog.9985.jpg
#   inflating: ./dogcat/train/dog.9986.jpg
#   inflating: ./dogcat/train/dog.9987.jpg
#   inflating: ./dogcat/train/dog.9988.jpg
#   inflating: ./dogcat/train/dog.9989.jpg
#   inflating: ./dogcat/train/dog.999.jpg
#   inflating: ./dogcat/train/dog.9990.jpg
#   inflating: ./dogcat/train/dog.9991.jpg
#   inflating: ./dogcat/train/dog.9992.jpg
#   inflating: ./dogcat/train/dog.9993.jpg
#   inflating: ./dogcat/train/dog.9994.jpg
#   inflating: ./dogcat/train/dog.9995.jpg
#   inflating: ./dogcat/train/dog.9996.jpg
#   inflating: ./dogcat/train/dog.9997.jpg
#   inflating: ./dogcat/train/dog.9998.jpg
#   inflating: ./dogcat/train/dog.9999.jpg

# %% [markdown]
# Мы скачали данные. Давайте ниже напишем класс датасета. Формат данных у нас следующий: если в названии файла есть cat, то на картинке котик. А если dog, то пёсик.

# %%
import numpy as np
import pandas as pd
from glob import glob

import torch
from torch import nn

import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
import time
import os
from tqdm import tqdm
from tempfile import TemporaryDirectory

from PIL import Image

# %% [markdown]
# Подготовим данные и разделим их на трейн и тест

# %%
images = glob("./dogcat/train/*.jpg")

# %%
train, test = train_test_split(images, test_size = 0.3, random_state=42)

# %%
class CatDogDataset(Dataset):

    def __init__(self, paths, transform = None):

        self.paths = paths
        self.transform = transform


    def __len__(self):
        return len(self.paths)

    def __getitem__(self, index):
        label = self.paths[index].split("/")[-1].split(".")[0]

        label = 0 if label == 'cat' else 1

        image = Image.open(self.paths[index])

        if self.transform is not None:
            image = self.transform(image)

        return image, label

# %%
# Сделаем просто ресайз и нормалайз
data_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
import matplotlib.pyplot as plt

def imshow(inp):
    """Display image for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    plt.axis("off")
    plt.pause(0.001)  # pause a bit so that plots are updated

# %%
data = {"train": train, "val" : test}
image_datasets = {x: CatDogDataset(data[x], transform=data_transform)
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=32,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()

# %%
# Отрисуем одну картинку
imshow(image_datasets["train"].__getitem__(0)[0])

# %%
def train_model(model, criterion, optimizer, num_epochs=25):
    since = time.time()

    # Create a temporary directory to save training checkpoints
    with TemporaryDirectory() as tempdir:
        best_model_params_path = os.path.join(tempdir, 'best_model_params.pt')

        torch.save(model.state_dict(), best_model_params_path)
        best_acc = 0.0

        for epoch in range(num_epochs):
            print(f'Epoch {epoch}/{num_epochs - 1}')
            print('-' * 10)

            # Each epoch has a training and validation phase
            for phase in ['train', 'val']:
                if phase == 'train':
                    model.train()  # Set model to training mode
                else:
                    model.eval()   # Set model to evaluate mode

                running_loss = 0.0
                running_corrects = 0

                # Iterate over data.
                for inputs, labels in tqdm(dataloaders[phase]):
                    inputs = inputs.to(device)
                    labels = labels.to(device)

                    # zero the parameter gradients
                    optimizer.zero_grad()

                    # forward
                    # track history if only in train
                    with torch.set_grad_enabled(phase == 'train'):
                        outputs = model(inputs)
                        _, preds = torch.max(outputs, 1)
                        loss = criterion(outputs, labels)

                        # backward + optimize only if in training phase
                        if phase == 'train':
                            loss.backward()
                            optimizer.step()

                    # statistics
                    running_loss += loss.item() * inputs.size(0)
                    running_corrects += torch.sum(preds == labels.data)

                epoch_loss = running_loss / dataset_sizes[phase]
                epoch_acc = running_corrects.double() / dataset_sizes[phase]

                print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

                # deep copy the model
                if phase == 'val' and epoch_acc > best_acc:
                    best_acc = epoch_acc
                    torch.save(model.state_dict(), best_model_params_path)

            print()

        time_elapsed = time.time() - since
        print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
        print(f'Best val Acc: {best_acc:4f}')

        # load best model weights
        model.load_state_dict(torch.load(best_model_params_path))
    return model

# %%
class_names = {0 : "cat", 1:"dog"}

def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title(f'predicted: {class_names[int(preds[j])]}')
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %% [markdown]
# Далее вам нужно взять модель ResNet 18 и дообучить её на нашем датасете. Также понадобится посчитать количество параметров модели. Вы можете использовать любой код, а можете придерживаться примера ниже.
#
# Код очень похож на первый видеоурок темы компьютерного зрения, не стесняйтесь туда подглядывать!

# %% [markdown]
# Ниже нужно обозначить модель, вызвать функцию обучения, и поработать с моделью.

# %%
torchvision.models.resnet18(weights='IMAGENET1K_V1')
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 189MB/s]
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %%
model = torchvision.models.resnet18(weights='IMAGENET1K_V1')

num_f_fc = model.fc.in_features
model.fc = nn.Linear(num_f_fc, 2)

model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# ## Задание 1. Посчитайте число параметров в модели
#
# ## Задание 2. Посчитайте Params size (MB)

# %%
# !pip install torchinfo
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
from torchinfo import summary

summary(model, input_size=(1, 3, 224, 224))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ResNet                                   [1, 2]                    --
# ├─Conv2d: 1-1                            [1, 64, 112, 112]         9,408
# ├─BatchNorm2d: 1-2                       [1, 64, 112, 112]         128
# ├─ReLU: 1-3                              [1, 64, 112, 112]         --
# ├─MaxPool2d: 1-4                         [1, 64, 56, 56]           --
# ├─Sequential: 1-5                        [1, 64, 56, 56]           --
# │    └─BasicBlock: 2-1                   [1, 64, 56, 56]           --
# │    │    └─Conv2d: 3-1                  [1, 64, 56, 56]           36,864
# │    │    └─BatchNorm2d: 3-2             [1, 64, 56, 56]           128
# │    │    └─ReLU: 3-3                    [1, 64, 56, 56]           --
# │    │    └─Conv2d: 3-4                  [1, 64, 56, 56]           36,864
# │    │    └─BatchNorm2d: 3-5             [1, 64, 56, 56]           128
# │    │    └─ReLU: 3-6                    [1, 64, 56, 56]           --
# │    └─BasicBlock: 2-2                   [1, 64, 56, 56]           --
# │    │    └─Conv2d: 3-7                  [1, 64, 56, 56]           36,864
# │    │    └─BatchNorm2d: 3-8             [1, 64, 56, 56]           128
# │    │    └─ReLU: 3-9                    [1, 64, 56, 56]           --
# │    │    └─Conv2d: 3-10                 [1, 64, 56, 56]           36,864
# │    │    └─BatchNorm2d: 3-11            [1, 64, 56, 56]           128
# │    │    └─ReLU: 3-12                   [1, 64, 56, 56]           --
# ├─Sequential: 1-6                        [1, 128, 28, 28]          --
# │    └─BasicBlock: 2-3                   [1, 128, 28, 28]          --
# │    │    └─Conv2d: 3-13                 [1, 128, 28, 28]          73,728
# │    │    └─BatchNorm2d: 3-14            [1, 128, 28, 28]          256
# │    │    └─ReLU: 3-15                   [1, 128, 28, 28]          --
# │    │    └─Conv2d: 3-16                 [1, 128, 28, 28]          147,456
# │    │    └─BatchNorm2d: 3-17            [1, 128, 28, 28]          256
# │    │    └─Sequential: 3-18             [1, 128, 28, 28]          8,448
# │    │    └─ReLU: 3-19                   [1, 128, 28, 28]          --
# │    └─BasicBlock: 2-4                   [1, 128, 28, 28]          --
# │    │    └─Conv2d: 3-20                 [1, 128, 28, 28]          147,456
# │    │    └─BatchNorm2d: 3-21            [1, 128, 28, 28]          256
# │    │    └─ReLU: 3-22                   [1, 128, 28, 28]          --
# │    │    └─Conv2d: 3-23                 [1, 128, 28, 28]          147,456
# │    │    └─BatchNorm2d: 3-24            [1, 128, 28, 28]          256
# │    │    └─ReLU: 3-25                   [1, 128, 28, 28]          --
# ├─Sequential: 1-7                        [1, 256, 14, 14]          --
# │    └─BasicBlock: 2-5                   [1, 256, 14, 14]          --
# │    │    └─Conv2d: 3-26                 [1, 256, 14, 14]          294,912
# │    │    └─BatchNorm2d: 3-27            [1, 256, 14, 14]          512
# │    │    └─ReLU: 3-28                   [1, 256, 14, 14]          --
# │    │    └─Conv2d: 3-29                 [1, 256, 14, 14]          589,824
# │    │    └─BatchNorm2d: 3-30            [1, 256, 14, 14]          512
# │    │    └─Sequential: 3-31             [1, 256, 14, 14]          33,280
# │    │    └─ReLU: 3-32                   [1, 256, 14, 14]          --
# │    └─BasicBlock: 2-6                   [1, 256, 14, 14]          --
# │    │    └─Conv2d: 3-33                 [1, 256, 14, 14]          589,824
# │    │    └─BatchNorm2d: 3-34            [1, 256, 14, 14]          512
# │    │    └─ReLU: 3-35                   [1, 256, 14, 14]          --
# │    │    └─Conv2d: 3-36                 [1, 256, 14, 14]          589,824
# │    │    └─BatchNorm2d: 3-37            [1, 256, 14, 14]          512
# │    │    └─ReLU: 3-38                   [1, 256, 14, 14]          --
# ├─Sequential: 1-8                        [1, 512, 7, 7]            --
# │    └─BasicBlock: 2-7                   [1, 512, 7, 7]            --
# │    │    └─Conv2d: 3-39                 [1, 512, 7, 7]            1,179,648
# │    │    └─BatchNorm2d: 3-40            [1, 512, 7, 7]            1,024
# │    │    └─ReLU: 3-41                   [1, 512, 7, 7]            --
# │    │    └─Conv2d: 3-42                 [1, 512, 7, 7]            2,359,296
# │    │    └─BatchNorm2d: 3-43            [1, 512, 7, 7]            1,024
# │    │    └─Sequential: 3-44             [1, 512, 7, 7]            132,096
# │    │    └─ReLU: 3-45                   [1, 512, 7, 7]            --
# │    └─BasicBlock: 2-8                   [1, 512, 7, 7]            --
# │    │    └─Conv2d: 3-46                 [1, 512, 7, 7]            2,359,296
# │    │    └─BatchNorm2d: 3-47            [1, 512, 7, 7]            1,024
# │    │    └─ReLU: 3-48                   [1, 512, 7, 7]            --
# │    │    └─Conv2d: 3-49                 [1, 512, 7, 7]            2,359,296
# │    │    └─BatchNorm2d: 3-50            [1, 512, 7, 7]            1,024
# │    │    └─ReLU: 3-51                   [1, 512, 7, 7]            --
# ├─AdaptiveAvgPool2d: 1-9                 [1, 512, 1, 1]            --
# ├─Linear: 1-10                           [1, 2]                    1,026
# ==========================================================================================
# Total params: 11,177,538
# Trainable params: 11,177,538
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 1.81
# ==========================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 39.74
# Params size (MB): 44.71
# Estimated Total Size (MB): 85.05
# ==========================================================================================

# %% [markdown]
# ## Задание 3. Обучите модель на 5 эпохах и запомните (или запишите) accuracy. Это понадобится для ответа на вопрос теста. Запомните и качество после первой эпохи.
#
# Будьте готовы, что обучение займет минут 10 на ГПУ в коллабе. Это ещё быстро...

# %%
model = train_model(model, criterion, optimizer, num_epochs=5)
# Out:
# Epoch 0/4
# ----------
#   0%|          | 0/547 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:432: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# 100%|██████████| 547/547 [01:17<00:00,  7.06it/s]
# train Loss: 0.1720 Acc: 0.9293
# 100%|██████████| 235/235 [00:26<00:00,  8.98it/s]
# val Loss: 0.2101 Acc: 0.9132
#
# Epoch 1/4
# ----------
# 100%|██████████| 547/547 [01:11<00:00,  7.66it/s]
# train Loss: 0.1079 Acc: 0.9570
# 100%|██████████| 235/235 [00:26<00:00,  8.75it/s]
# val Loss: 0.1327 Acc: 0.9457
#
# Epoch 2/4
# ----------
# 100%|██████████| 547/547 [01:11<00:00,  7.65it/s]
# train Loss: 0.1025 Acc: 0.9593
# 100%|██████████| 235/235 [00:26<00:00,  8.76it/s]
# val Loss: 0.1040 Acc: 0.9592
#
# Epoch 3/4
# ----------
# 100%|██████████| 547/547 [01:10<00:00,  7.71it/s]
# train Loss: 0.0858 Acc: 0.9677
# 100%|██████████| 235/235 [00:25<00:00,  9.08it/s]
# val Loss: 0.0802 Acc: 0.9683
#
# Epoch 4/4
# ----------
# 100%|██████████| 547/547 [01:10<00:00,  7.72it/s]
# train Loss: 0.0622 Acc: 0.9755
# 100%|██████████| 235/235 [00:25<00:00,  9.06it/s]
# val Loss: 0.1356 Acc: 0.9419
#
# Training complete in 8m 14s
# Best val Acc: 0.968267

# %% [markdown]
# ## Задание 4. Сделайте то же самое, только без предобученной архитектуры. Это задается параметром weights со значением None. Стало ли качество лучше? Запомните и его.

# %%
model_zero = torchvision.models.resnet18(weights=None)

zero_num_f_fc = model_zero.fc.in_features
model_zero.fc = nn.Linear(zero_num_f_fc, 2)

model_zero.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model_zero.parameters(), lr=0.001)

# %%
zero_model = train_model(model_zero, criterion, optimizer, num_epochs=5)
# Out:
# Epoch 0/4
# ----------
# 100%|██████████| 547/547 [01:11<00:00,  7.66it/s]
# train Loss: 0.6495 Acc: 0.6227
# 100%|██████████| 235/235 [00:25<00:00,  9.19it/s]
# val Loss: 0.7940 Acc: 0.5592
#
# Epoch 1/4
# ----------
# 100%|██████████| 547/547 [01:10<00:00,  7.72it/s]
# train Loss: 0.5600 Acc: 0.7103
# 100%|██████████| 235/235 [00:25<00:00,  9.10it/s]
# val Loss: 0.8188 Acc: 0.6009
#
# Epoch 2/4
# ----------
# 100%|██████████| 547/547 [01:10<00:00,  7.76it/s]
# train Loss: 0.5106 Acc: 0.7467
# 100%|██████████| 235/235 [00:25<00:00,  9.13it/s]
# val Loss: 0.5156 Acc: 0.7448
#
# Epoch 3/4
# ----------
# 100%|██████████| 547/547 [01:10<00:00,  7.73it/s]
# train Loss: 0.4691 Acc: 0.7755
# 100%|██████████| 235/235 [00:25<00:00,  9.09it/s]
# val Loss: 0.4771 Acc: 0.7659
#
# Epoch 4/4
# ----------
# 100%|██████████| 547/547 [01:10<00:00,  7.73it/s]
# train Loss: 0.4224 Acc: 0.8068
# 100%|██████████| 235/235 [00:25<00:00,  9.25it/s]
# val Loss: 0.4663 Acc: 0.7967
#
# Training complete in 8m 3s
# Best val Acc: 0.796667

# %% [markdown]
# Посмотрим чему научилась наша модель, обученная с 0:

# %%
visualize_model(model_zero)

plt.ioff()
plt.show()

# %% [markdown]
# А с претрейном:

# %%
visualize_model(model)

plt.ioff()
plt.show()

# %% [markdown]
# Отлично, вы справились с задачей и изучили основы компьютерного зрения! Дальше нас ждет захватывающий мир современного CV.
